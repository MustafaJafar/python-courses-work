# %%
#you can grab each page manully 
#or better : figure out the rule of how page i=url changes 
import requests , pandas
from bs4 import BeautifulSoup

#get web page #00 == first page , 10 == second , 20 == third
base_url = "https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s="
#list to hold the data
l = []
#you can set the range manully or you can set number of pages automatically 
#page_nr = soup.find_all("a" , {"class" : "Page"})[-1].text #this will return 3
#page_nr = int(page_nr) * 10 #will = 30

#for pages in range(0 , page_nr , 10) :
for pages in range(0 , 30 , 10) :
    req = requests.get(base_url+str(pages)+".html")
    #load content
    cont = req.content

    soup = BeautifulSoup(cont , "html.parser")
    
    all = soup.find_all("div" , {"class" : "propertyRow"})
    
    
    
    for item in all : 
        d = {}

        d["Address"] = item.find_all("span" , {"class" : "propAddressCollapse"})[0].text
        d["Price"] = item.find_all("h4" , {"class" : "propPrice"})[0].text.replace("\n" ,"")

        try :
            d["Locality"] = item.find_all("span" , {"class" : "propAddressCollapse"})[1].text
        except : 
            d["Locality"] = None
            
        try :
            d["Beds"] = item.find_all("span" , {"class" : "infoBed"})[0].text
        except : 
            d["Beds"]= None
        try :
            d["Area"] = None
        except : 
            d["Area"] = item.find_all("span" , {"class" : "infoSqft"})[0].text
        try : 
            d["Full Baths"] = item.find_all("span" , {"class" : "infoValueFullBath"})[0].text
        except :
            d["Full Baths"] = None
        try : 
            d["Half Baths"] = item.find_all("span" , {"class" : "infoValueHalfBath"})[0].text
        except :
            d["Half Baths"] = None

        for column_group in item.find_all("div" , {"class" : "columnGroup"}) : 
            for feature_group , feature_name in zip (column_group.find_all("span" , {"class" : "featureGroup"}) ,column_group.find_all("span" , {"class" : "featureName"}) ) :
                if ("Lot Size" in feature_group.text) : 
                    d["Lot Size"] = feature_name.text
        l.append(d)
    
df = pandas.DataFrame(l , columns =['Address' , 'Locality' , 'Area' ,'Lot Size', 'Price' ,'Beds', 'Full Baths', 'Half Baths' ])
df.to_csv("2_Output.csv")
df
# Out:
#                   Address                Locality  Area          Lot Size  \
# 0               0 Gateway  Rock Springs, WY 82901  None               NaN
# 1   1003 Winchester Blvd.  Rock Springs, WY 82901  None        0.21 Acres
# 2           600 Talladega  Rock Springs, WY 82901  None               NaN
# 3      3239 Spearhead Way  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 4      522 Emerald Street  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 5    1302 Veteran's Drive  Rock Springs, WY 82901  None        0.27 Acres
# 6        1021 Cypress Cir  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 7          913 Madison Dr  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 8       1344 Teton Street  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 9          4 Minnies Lane  Rock Springs, WY 82901  None        2.02 Acres
# 10              0 Gateway  Rock Springs, WY 82901  None               NaN
# 11  1003 Winchester Blvd.  Rock Springs, WY 82901  None        0.21 Acres
# 12          600 Talladega  Rock Springs, WY 82901  None               NaN
# 13     3239 Spearhead Way  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 14     522 Emerald Street  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 15   1302 Veteran's Drive  Rock Springs, WY 82901  None        0.27 Acres
# 16       1021 Cypress Cir  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 17         913 Madison Dr  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 18      1344 Teton Street  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 19         4 Minnies Lane  Rock Springs, WY 82901  None        2.02 Acres
# 20              0 Gateway  Rock Springs, WY 82901  None               NaN
# 21  1003 Winchester Blvd.  Rock Springs, WY 82901  None        0.21 Acres
# 22          600 Talladega  Rock Springs, WY 82901  None               NaN
# 23     3239 Spearhead Way  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 24     522 Emerald Street  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 25   1302 Veteran's Drive  Rock Springs, WY 82901  None        0.27 Acres
# 26       1021 Cypress Cir  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 27         913 Madison Dr  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 28      1344 Teton Street  Rock Springs, WY 82901  None  Under 1/2 Acre,
# 29         4 Minnies Lane  Rock Springs, WY 82901  None        2.02 Acres
#
#         Price    Beds    Full Baths   Half Baths
# 0    $725,000    None          None         None
# 1    $452,900  4 Beds  4 Full Baths         None
# 2    $396,900  5 Beds  3 Full Baths         None
# 3    $389,900  4 Beds  3 Full Baths  1 Half Bath
# 4    $254,000  3 Beds  3 Full Baths         None
# 5    $252,900  4 Beds  2 Full Baths         None
# 6    $210,000  4 Beds  3 Full Baths         None
# 7    $209,000  3 Beds  2 Full Baths         None
# 8    $199,900  3 Beds  2 Full Baths         None
# 9    $196,900  3 Beds  2 Full Baths         None
# 10   $725,000    None          None         None
# 11   $452,900  4 Beds  4 Full Baths         None
# 12   $396,900  5 Beds  3 Full Baths         None
# 13   $389,900  4 Beds  3 Full Baths  1 Half Bath
# 14   $254,000  3 Beds  3 Full Baths         None
# 15   $252,900  4 Beds  2 Full Baths         None
# 16   $210,000  4 Beds  3 Full Baths         None
# 17   $209,000  3 Beds  2 Full Baths         None
# 18   $199,900  3 Beds  2 Full Baths         None
# 19   $196,900  3 Beds  2 Full Baths         None
# 20   $725,000    None          None         None
# 21   $452,900  4 Beds  4 Full Baths         None
# 22   $396,900  5 Beds  3 Full Baths         None
# 23   $389,900  4 Beds  3 Full Baths  1 Half Bath
# 24   $254,000  3 Beds  3 Full Baths         None
# 25   $252,900  4 Beds  2 Full Baths         None
# 26   $210,000  4 Beds  3 Full Baths         None
# 27   $209,000  3 Beds  2 Full Baths         None
# 28   $199,900  3 Beds  2 Full Baths         None
# 29   $196,900  3 Beds  2 Full Baths         None
